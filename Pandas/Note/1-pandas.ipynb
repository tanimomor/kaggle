# %%
import pandas as pd
reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", index_col=0)
pd.set_option('display.max_rows', 5)
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
pd.DataFrame([[30, 21]], columns=['Apples', 'Bananas'])
# Out:
#    Apples  Bananas
# 0      30       21

# %%
quantities = ['4 cups', '1 cup', '2 large', '1 can']
items = ['Flour', 'Milk', 'Eggs', 'Spam']
recipe = pd.Series(quantities, index=items, name='Dinner')
recipe
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
pd.read_csv('/kaggle/input/wine-reviews/winemag-data_first150k.csv', index_col=0)
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# ...        ...                                                ...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# ...                                      ...     ...    ...
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province     region_1 region_2             variety  \
# 0               California  Napa Valley     Napa  Cabernet Sauvignon
# ...

# %%
wine_reviews = pd.read_csv('/kaggle/input/wine-reviews/winemag-data-130k-v2.csv')
wine_reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
wine_reviews.shape
# Out:
# (129971, 14)

# %%
# The pd.read_csv() function is well-endowed, with over 30 optional parameters you can specify. For example, 
# you can see in this dataset that the CSV file has a built-in index, which pandas did not pick up on automatically.
wine_reviews = pd.read_csv('/kaggle/input/wine-reviews/winemag-data-130k-v2.csv', index_col=0)
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals
animals.to_csv('animals.csv')

# %% [markdown]
# **Indexing, Selecting & Assigning**

# %%
reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", index_col=0)
pd.set_option('display.max_rows', 5)
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.country
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews['country']
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews['country'][0]
# Out:
# 'Italy'

# %% [markdown]
# **Indexing**

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
reviews.iloc[:, 0]
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews.iloc[:3, 0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
reviews.iloc[[0, 1, 2], 0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
reviews.iloc[-5:]
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
reviews.iloc[::-1]
# Out:
#          country                                        description  \
# 129970    France  Big, rich and off-dry, this is powered by inte...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# ...          ...                                                ...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 0          Italy  Aromas include tropical fruit, broom, brimston...
#
#                           designation  points  price           province  \
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
# 129969                            NaN      90   32.0             Alsace
# ...                               ...     ...    ...                ...
# 1                            Avidagos      87   15.0              Douro
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.loc[0, 'country']
# Out:
# 'Italy'

# %%
reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#           taster_name taster_twitter_handle  points
# 0       Kerin O’Keefe          @kerinokeefe      87
# 1          Roger Voss            @vossroger      87
# ...               ...                   ...     ...
# 129969     Roger Voss            @vossroger      90
# 129970     Roger Voss            @vossroger      90
#
# [129971 rows x 3 columns]

# %% [markdown]
# * Iloc uses the stdlib indexing scheme. 0:10 0,...,9
# * loc indexes inclusively. 0:10 0,...,10

# %% [markdown]
# Critically, the index we use is not immutable. We can manipulate the index in any way we see fit.
#
# The set_index() method can be used to do the job. Here is what happens when we set_index to the title field

# %%
reviews.set_index('title').head()
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# Rainstorm 2013 Pinot Gris (Willamette Valley)       Tart and snappy, the flavors of lime flesh and...
# St. Julian 2013 Reserve Late Harvest Riesling (...  Pineapple rind, lemon pith and orange blossom ...
# ...

# %%
reviews.country == 'Italy'
# Out:
# 0          True
# 1         False
#           ...
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
# Can't use with iloc
reviews.loc[reviews.country == 'Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.loc[(reviews.country == 'Italy') & (reviews.points <= 90), ['country', 'points']]
# Out:
#        country  points
# 0        Italy      87
# 6        Italy      87
# ...        ...     ...
# 129961   Italy      90
# 129962   Italy      90
#
# [15275 rows x 2 columns]
#        country  points
# 0        Italy      87
# 6        Italy      87
# ...        ...     ...
# 129961   Italy      90
# 129962   Italy      90
#
# [15275 rows x 2 columns]

# %%
reviews.loc[(reviews['country'] == 'Italy') | (reviews['points'] >= 90), ['country', 'points']]
# Out:
#        country  points
# 0        Italy      87
# 6        Italy      87
# ...        ...     ...
# 129969  France      90
# 129970  France      90
#
# [61937 rows x 2 columns]

# %%
reviews.loc[reviews.country.isin(['Italy', 'France']), ['country', 'points']]
# Out:
#        country  points
# 0        Italy      87
# 6        Italy      87
# ...        ...     ...
# 129969  France      90
# 129970  France      90
#
# [41633 rows x 2 columns]

# %%
reviews.loc[reviews.price.notnull(), ['price']]
# Out:
#         price
# 1        15.0
# 2        14.0
# ...       ...
# 129969   32.0
# 129970   21.0
#
# [120975 rows x 1 columns]

# %%
reviews['critic'] = 'everyone'
reviews['critic']
# Out:
# 0         everyone
# 1         everyone
#             ...
# 129969    everyone
# 129970    everyone
# Name: critic, Length: 129971, dtype: object

# %%
indices = [1, 2, 3, 5, 8]
sample_reviews = reviews.loc[indices]
sample_reviews
# Out:
#     country                                        description  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 5     Spain  Blackberry and raspberry aromas show a typical...
# 8   Germany  Savory dried thyme notes accent sunnier flavor...
#
#             designation  points  price        province             region_1  \
# 1              Avidagos      87   15.0           Douro                  NaN
# 2                   NaN      87   14.0          Oregon    Willamette Valley
# 3  Reserve Late Harvest      87   13.0        Michigan  Lake Michigan Shore
# 5          Ars In Vitro      87   15.0  Northern Spain              Navarra
# 8                 Shine      87   12.0     Rheinhessen                  NaN
#
#             region_2         taster_name taster_twitter_handle  \
# ...

# %%
import numpy as np

df = pd.DataFrame(
    [
        ['Italy', 'Sicily & Sardinia', 'Etna', np.NaN],
        ['Portugal', 'Douro', np.NaN, np.NaN],
        ['US', 'California', 'Napa Valley', 'Napa'],
        ['US', 'New York', 'Finger Lakes', 'Finger Lakes']
    ],
    columns=['country', 'province', 'region_1', 'region_2'],
    index=[0, 1, 10, 100]
)
df
# Out:
#       country           province      region_1      region_2
# 0       Italy  Sicily & Sardinia          Etna           NaN
# 1    Portugal              Douro           NaN           NaN
# 10         US         California   Napa Valley          Napa
# 100        US           New York  Finger Lakes  Finger Lakes

# %%
cols = ['country', 'province', 'region_1', 'region_2']
indices = [0, 1, 10, 100]
df = reviews.loc[indices, cols]
df
# Out:
#       country           province      region_1      region_2
# 0       Italy  Sicily & Sardinia          Etna           NaN
# 1    Portugal              Douro           NaN           NaN
# 10         US         California   Napa Valley          Napa
# 100        US           New York  Finger Lakes  Finger Lakes

# %%
cols = ['country', 'variety']
df = reviews.loc[:99, cols]

# Same

cols_idx = [0, 11]
df = reviews.iloc[:100, cols_idx]
df
# Out:
#      country                   variety
# 0      Italy               White Blend
# 1   Portugal            Portuguese Red
# ..       ...                       ...
# 98     Italy                Sangiovese
# 99        US  Bordeaux-style Red Blend
#
# [100 rows x 2 columns]

# %%
top_oceania_wines = reviews.loc[
    (reviews.country.isin(['Australia', 'New Zealand']))
    & (reviews.points >= 95)
]

# %%
reviews.describe()
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# ...              ...            ...
# 75%        91.000000      42.000000
# max       100.000000    3300.000000
#
# [8 rows x 2 columns]

# %%
reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
#              ...
# 75%          91.000000
# max         100.000000
# Name: points, Length: 8, dtype: float64

# %%
reviews.taster_name.describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
reviews.points.mean()
# Out:
# 88.44713820775404

# %%
reviews.taster_name.unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
reviews.taster_name.value_counts()
# Out:
# taster_name
# Roger Voss           25514
# Michael Schachner    15134
#                      ...
# Fiona Adams             27
# Christina Pickard        6
# Name: count, Length: 19, dtype: int64

# %%
review_points_mean = reviews.points.mean()
reviews.points.map(lambda p: p - review_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
def remean_points(row):
    row.points = row.points - review_points_mean
    return row

reviews.apply(remean_points, axis='columns')
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation    points  price           province  \
# 0                        Vulkà Bianco -1.447138    NaN  Sicily & Sardinia
# 1                            Avidagos -1.447138   15.0              Douro
# ...                               ...       ...    ...                ...
# 129969                            NaN  1.552862   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline  1.552862   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.loc[0, 'country']
# Out:
# 'Italy'

# %%
reviews.loc[:, ('taster_name', 'taster_twitter_handle', 'points')]
# Out:
#           taster_name taster_twitter_handle  points
# 0       Kerin O’Keefe          @kerinokeefe      87
# 1          Roger Voss            @vossroger      87
# ...               ...                   ...     ...
# 129969     Roger Voss            @vossroger      90
# 129970     Roger Voss            @vossroger      90
#
# [129971 rows x 3 columns]

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews.index_backwards
# Out:
# 0         129971
# 1         129970
#            ...
# 129969         2
# 129970         1
# Name: index_backwards, Length: 129971, dtype: int64

# %% [markdown]
# **Summary Functions and Maps**

# %%
reviews.points.mean()
# Out:
# 88.44713820775404

# %%
reviews.taster_name.unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
reviews.taster_name.value_counts()
# Out:
# taster_name
# Roger Voss           25514
# Michael Schachner    15134
#                      ...
# Fiona Adams             27
# Christina Pickard        6
# Name: count, Length: 19, dtype: int64

# %% [markdown]
# map() and apply() return new, transformed Series and DataFrames

# %%
review_points_mean = reviews.points.mean()
reviews.points.map(lambda p: p - review_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %% [markdown]
# Apply if we want to transform whole DataFrame

# %% [markdown]
# If we had called reviews.apply() with axis='index', then instead of passing a function to transform each row, we would need to give a function to transform each column.

# %%
def remean_points(row):
    row.points - review_points_mean
    return row

reviews.apply(remean_points, axis='columns')
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
def stars(row):
    if row.country == 'Canada':
        return 3
    elif row.points >= 95:
        return 3
    elif row.points >= 85:
        return 2
    else:
        return 1

star_ratings = reviews.apply(stars, axis='columns')

# %%
reviews.head(1)
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                              title      variety  \
# 0          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
#
#     winery    critic  index_backwards
# 0  Nicosia  everyone           129971

# %%
review_points_mean = reviews.points.mean()
reviews.points - review_points_mean
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
country_and_region = reviews.country + '-' + reviews.region_1
country_and_region
# Out:
# 0            Italy-Etna
# 1                   NaN
#               ...
# 129969    France-Alsace
# 129970    France-Alsace
# Length: 129971, dtype: object

# %%
median_points = reviews.points.median()

# %%
reviews.loc[(reviews.points / reviews.price)==(reviews.points / reviews.price).max()]
# Out:
#         country                                        description  \
# 64590        US  There's a lot going on in this Merlot, which i...
# 126096  Romania  Notes of sun-dried hay and green flower highli...
#
#        designation  points  price         province    region_1  \
# 64590          NaN      86    4.0       California  California
# 126096     UnWineD      86    4.0  Viile Timisului         NaN
#
#                 region_2         taster_name taster_twitter_handle  \
# 64590   California Other                 NaN                   NaN
# 126096               NaN  Anna Lee C. Iijima                   NaN
#
#                                                     title       variety  \
# 64590                       Bandit NV Merlot (California)        Merlot
# 126096  Cramele Recas 2011 UnWineD Pinot Grigio (Viile...  Pinot Grigio
#
#                winery    critic  index_backwards
# 64590          Bandit  everyone            65381
# ...

# %%
(reviews.points / reviews.price).idxmax()
# Out:
# 64590

# %%
'x yz'.count('x')
# Out:
# 1

# %%
reviews.description.map(lambda d: d.count('tropical')+d.count('fruity')).sum()
# Out:
# 12962

# %%
# Presence check
n_trop = reviews.description.map(lambda desc: "tropical" in desc).sum()
n_fruity = reviews.description.map(lambda desc: "fruity" in desc).sum()
descriptor_counts = pd.Series([n_trop, n_fruity], index=['tropical', 'fruity'])
descriptor_counts
# Out:
# tropical    3607
# fruity      9090
# dtype: int64

# %%
# Occurance check
n_trop = reviews.description.map(lambda d: d.count('tropical')).sum()
n_fruity = reviews.description.map(lambda d: d.count('fruity')).sum()
descriptor_counts = pd.Series([n_trop, n_fruity], index=['tropical', 'fruity'])
descriptor_counts
# Out:
# tropical    3703
# fruity      9259
# dtype: int64

# %% [markdown]
# **Grouping and Sorting**

# %%
reviews.groupby('points').count()
# Out:
#         country  description  designation  price  province  region_1  \
# points
# 80          397          397          250    395       397       328
# 81          692          692          406    680       692       584
# ...         ...          ...          ...    ...       ...       ...
# 99           33           33           29     28        33        31
# 100          19           19           13     19        19        17
#
#         region_2  taster_name  taster_twitter_handle  title  variety  winery  \
# points
# 80           136          275                    271    397      397     397
# 81           293          433                    423    692      692     692
# ...          ...          ...                    ...    ...      ...     ...
# 99            12           21                     21     33       33      33
# 100            4           14                     14     19       19      19
#
#         critic  index_backwards
# points
# ...

# %%
reviews.groupby('points').designation.count()
# Out:
# points
# 80     250
# 81     406
#       ...
# 99      29
# 100     13
# Name: designation, Length: 21, dtype: int64

# %%
reviews.groupby('points').price.max()
# Out:
# points
# 80       69.0
# 81      130.0
#         ...
# 99      850.0
# 100    1500.0
# Name: price, Length: 21, dtype: float64

# %%
reviews.groupby('points').price.count()
# Out:
# points
# 80     395
# 81     680
#       ...
# 99      28
# 100     19
# Name: price, Length: 21, dtype: int64

# %%
reviews.loc[:, ['winery', 'title']]
# Out:
#                       winery  \
# 0                    Nicosia
# 1        Quinta dos Avidagos
# ...                      ...
# 129969  Domaine Marcel Deiss
# 129970      Domaine Schoffit
#
#                                                     title
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)
# ...                                                   ...
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
# [129971 rows x 2 columns]

# %%
reviews.groupby('winery').apply(lambda df: df.title.iloc[-1])
# Out:
# /tmp/ipykernel_34/1565636518.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   reviews.groupby('winery').apply(lambda df: df.title.iloc[-1])
# winery
# 1+1=3                       1+1=3 NV Brut Sparkling (Cava)
# 10 Knots    10 Knots 2009 Moonraker Grenache (Paso Robles)
#                                  ...
# àMaurice    àMaurice NV Pour Me Red (Columbia Valley (WA))
# Štoka                      Štoka 2011 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# /tmp/ipykernel_34/506966275.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# winery
# 1+1=3                          1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                 10 Knots 2010 Viognier (Paso Robles)
#                                   ...
# àMaurice    àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                         Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
reviews.groupby('winery').title.count()
# Out:
# winery
# 1+1=3        6
# 10 Knots     4
#             ..
# àMaurice    40
# Štoka        3
# Name: title, Length: 16757, dtype: int64

# %%
reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# Out:
# /tmp/ipykernel_34/1865732994.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
#                               country  \
# country   province
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# ...                               ...
# Uruguay   San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Argentina Mendoza Province  If the color doesn't tell the full story, the ...
#           Other             Take note, this could be the best wine Colomé ...
# ...

# %% [markdown]
# groupby() method worth mentioning is agg(), which lets you run a bunch of different functions on your DataFrame simultaneously.

# %%
reviews.groupby(['country']).price.agg([len, min, max])
# Out:
# /tmp/ipykernel_34/4122224884.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   reviews.groupby(['country']).price.agg([len, min, max])
# /tmp/ipykernel_34/4122224884.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   reviews.groupby(['country']).price.agg([len, min, max])
#             len   min    max
# country
# Argentina  3800   4.0  230.0
# Armenia       2  14.0   15.0
# ...         ...   ...    ...
# Ukraine      14   6.0   13.0
# Uruguay     109  10.0  130.0
#
# [43 rows x 3 columns]

# %%
reviews.groupby('points').agg([len])
# Out:
#        country description designation price province region_1 region_2  \
#            len         len         len   len      len      len      len
# points
# 80         397         397         397   397      397      397      397
# 81         692         692         692   692      692      692      692
# ...        ...         ...         ...   ...      ...      ...      ...
# 99          33          33          33    33       33       33       33
# 100         19          19          19    19       19       19       19
#
#        taster_name taster_twitter_handle title variety winery critic  \
#                len                   len   len     len    len    len
# points
# 80             397                   397   397     397    397    397
# 81             692                   692   692     692    692    692
# ...            ...                   ...   ...     ...    ...    ...
# 99              33                    33    33      33     33     33
# ...

# %%
reviews.loc[(reviews.points == 80) & (reviews['designation'].notna()), ['designation']]
# Out:
#                  designation
# 344             Gran Reserva
# 3640                 Estreia
# ...                      ...
# 128261  Proprietor's Reserve
# 128262      Finca La Martina
#
# [250 rows x 1 columns]

# %%
reviews.groupby('points').count()
# Out:
#         country  description  designation  price  province  region_1  \
# points
# 80          397          397          250    395       397       328
# 81          692          692          406    680       692       584
# ...         ...          ...          ...    ...       ...       ...
# 99           33           33           29     28        33        31
# 100          19           19           13     19        19        17
#
#         region_2  taster_name  taster_twitter_handle  title  variety  winery  \
# points
# 80           136          275                    271    397      397     397
# 81           293          433                    423    692      692     692
# ...          ...          ...                    ...    ...      ...     ...
# 99            12           21                     21     33       33      33
# 100            4           14                     14     19       19      19
#
#         critic  index_backwards
# points
# ...

# %%
countries_reviewed = reviews.groupby(['country', 'province']).agg([len])
countries_reviewed
# Out:
#                            description designation points price region_1  \
#                                    len         len    len   len      len
# country   province
# Argentina Mendoza Province        3264        3264   3264  3264     3264
#           Other                    536         536    536   536      536
# ...                                ...         ...    ...   ...      ...
# Uruguay   San Jose                   3           3      3     3        3
#           Uruguay                   24          24     24    24       24
#
#                            region_2 taster_name taster_twitter_handle title  \
#                                 len         len                   len   len
# country   province
# Argentina Mendoza Province     3264        3264                  3264  3264
#           Other                 536         536                   536   536
# ...                             ...         ...                   ...   ...
# ...

# %%
# Sample data
data = {
    'category': ['A', 'A', 'B', 'B', 'B', 'C', 'C'],
    'value': [10, 20, 30, 30, 30, 60, 70],
    'other': [1, 2, 3, 3, 3, 6, 7]
}

df = pd.DataFrame(data)

# Group by 'category' and apply agg([len])
grouped = df.groupby('category').agg([len])

print(grouped)
# Out:
#          value other
#            len   len
# category
# A            2     2
# B            3     3
# C            2     2

# %%
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# ...                          ...
# Uruguay   San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
mi = countries_reviewed.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %% [markdown]
# Multi-indices have several methods for dealing with their tiered structure which are absent for single-level indices. They also require two levels of labels to retrieve a value.

# %% [markdown]
# Multi-indices have several methods for dealing with their tiered structure which are absent for single-level indices.

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# ..         ...               ...   ...
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %% [markdown]
# # Sorting
# sort_values() defaults to an ascending sort

# %%
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by='len')
# Out:
#     country               province    len
# 179  Greece  Muscat of Kefallonian      1
# 192  Greece          Sterea Ellada      1
# ..      ...                    ...    ...
# 415      US             Washington   8639
# 392      US             California  36247
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by='len', ascending=False)
# Out:
#     country    province    len
# 392      US  California  36247
# 415      US  Washington   8639
# ..      ...         ...    ...
# 63    Chile     Coelemu      1
# 149  Greece      Beotia      1
#
# [425 rows x 3 columns]

# %% [markdown]
# To sort by index values, use the companion method sort_index()

# %%
countries_reviewed.sort_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# ..         ...               ...   ...
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(['country', 'province'], ascending=False)
# Out:
#        country          province   len
# 424    Uruguay           Uruguay    24
# 423    Uruguay          San Jose     3
# ..         ...               ...   ...
# 1    Argentina             Other   536
# 0    Argentina  Mendoza Province  3264
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(['country', 'len'])
# Out:
#        country          province   len
# 1    Argentina             Other   536
# 0    Argentina  Mendoza Province  3264
# ..         ...               ...   ...
# 424    Uruguay           Uruguay    24
# 419    Uruguay         Canelones    43
#
# [425 rows x 3 columns]

# %%
reviews.loc[:,['taster_name', 'taster_twitter_handle']]
# Out:
#           taster_name taster_twitter_handle
# 0       Kerin O’Keefe          @kerinokeefe
# 1          Roger Voss            @vossroger
# ...               ...                   ...
# 129969     Roger Voss            @vossroger
# 129970     Roger Voss            @vossroger
#
# [129971 rows x 2 columns]

# %%
reviews_written = reviews.groupby('taster_twitter_handle').size()
reviews_written
# Out:
# taster_twitter_handle
# @AnneInVino        3685
# @JoeCz             5147
#                    ...
# @winewchristina       6
# @worldwineguys     1005
# Length: 15, dtype: int64

# %%
ans= reviews.groupby('taster_twitter_handle').taster_twitter_handle.count()
#Same:
# reviews_written = reviews.groupby('taster_twitter_handle').size()
ans
# Out:
# taster_twitter_handle
# @AnneInVino        3685
# @JoeCz             5147
#                    ...
# @winewchristina       6
# @worldwineguys     1005
# Name: taster_twitter_handle, Length: 15, dtype: int64

# %%
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
reviews.groupby('price').points.max().sort_index()
# Out:
# price
# 4.0       86
# 5.0       87
#           ..
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
reviews.variety
# Out:
# 0            White Blend
# 1         Portuguese Red
#                ...
# 129969        Pinot Gris
# 129970    Gewürztraminer
# Name: variety, Length: 129971, dtype: object

# %%
reviews.groupby('variety').price.agg([min, max])
# Out:
# /tmp/ipykernel_34/4155783549.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   reviews.groupby('variety').price.agg([min, max])
# /tmp/ipykernel_34/4155783549.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   reviews.groupby('variety').price.agg([min, max])
#               min   max
# variety
# Abouriou     15.0  75.0
# Agiorgitiko  10.0  66.0
# ...           ...   ...
# Çalkarası    19.0  19.0
# Žilavka      15.0  15.0
#
# [707 rows x 2 columns]

# %%
reviews.groupby('variety')[['price', 'points']].agg([min, max])
# Out:
# /tmp/ipykernel_34/1370736667.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   reviews.groupby('variety')[['price', 'points']].agg([min, max])
# /tmp/ipykernel_34/1370736667.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   reviews.groupby('variety')[['price', 'points']].agg([min, max])
# /tmp/ipykernel_34/1370736667.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# ...

# %%
sorted_varieties = reviews.groupby('variety')['price'].agg(['min', 'max']).sort_values(by=['min', 'max'], ascending=False)
sorted_varieties
# Out:
#              min    max
# variety
# Ramisco    495.0  495.0
# Terrantez  236.0  236.0
# ...          ...    ...
# Vital        NaN    NaN
# Zelen        NaN    NaN
#
# [707 rows x 2 columns]

# %%
reviews.taster_name.unique().shape
# Out:
# (20,)

# %%
reviews.groupby('taster_name').points.mean()
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
#                         ...
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, Length: 19, dtype: float64

# %%
reviewer_mean_ratings = reviews.groupby('taster_name').points.mean()
reviewer_mean_ratings
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
#                         ...
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, Length: 19, dtype: float64

# %%
reviewer_mean_ratings.index
# Out:
# Index(['Alexander Peartree', 'Anna Lee C. Iijima', 'Anne Krebiehl MW',
#        'Carrie Dykes', 'Christina Pickard', 'Fiona Adams', 'Jeff Jenssen',
#        'Jim Gordon', 'Joe Czerwinski', 'Kerin O’Keefe', 'Lauren Buzzeo',
#        'Matt Kettmann', 'Michael Schachner', 'Mike DeSimone', 'Paul Gregutt',
#        'Roger Voss', 'Sean P. Sullivan', 'Susan Kostrzewa', 'Virginie Boone'],
#       dtype='object', name='taster_name')

# %%
reviewer_mean_ratings.describe()
# Out:
# count    19.000000
# mean     88.233026
#            ...
# 75%      88.975256
# max      90.562551
# Name: points, Length: 8, dtype: float64

# %%
reviews.variety.unique().shape
# Out:
# (708,)

# %%
reviews.country.unique().shape
# Out:
# (44,)

# %%
reviews.groupby(['country', 'variety']).variety.size().sort_values(ascending=False)
# Out:
# country  variety
# US       Pinot Noir            9885
#          Cabernet Sauvignon    7315
#                                ...
# Mexico   Rosado                   1
# Uruguay  White Blend              1
# Name: variety, Length: 1612, dtype: int64

# %% [markdown]
# # Data Types

# %%
reviews.price.dtype
# Out:
# dtype('float64')

# %%
reviews.dtypes
# Out:
# country        object
# description    object
#                 ...
# variety        object
# winery         object
# Length: 13, dtype: object

# %%
reviews.points.astype('float64')
# Out:
# 0         87.0
# 1         87.0
#           ...
# 129969    90.0
# 129970    90.0
# Name: points, Length: 129971, dtype: float64

# %%
reviews.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Entries missing values are given the value NaN, short for "Not a Number". For technical reasons these NaN values are always of the float64 dtype.
#
# To select NaN entries you can use pd.isnull() (or its companion pd.notnull()). This is meant to be used thusly:

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews[pd.isnull(reviews.country)]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# ...        ...                                                ...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#            designation  points  price province region_1 region_2  \
# 913     Asureti Valley      87   30.0      NaN      NaN      NaN
# 3131          Partager      83    NaN      NaN      NaN      NaN
# ...                ...     ...    ...      ...      ...      ...
# 129590            Shah      90   30.0      NaN      NaN      NaN
# 129900             NaN      91   32.0      NaN      NaN      NaN
#
#           taster_name taster_twitter_handle  \
# 913     Mike DeSimone        @worldwineguys
# 3131       Roger Voss            @vossroger
# ...

# %%
reviews[pd.notnull(reviews.country)]
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.region_2[pd.notnull(reviews.region_2)].shape
# Out:
# (50511,)

# %%
reviews.region_2.fillna("Unknown").shape
# Out:
# (129971,)

# %% [markdown]
# We could fill each missing value with the first non-null value that appears sometime after the given record in the database. This is known as the backfill strategy

# %%
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# 0            @kerino
# 1         @vossroger
#              ...
# 129969    @vossroger
# 129970    @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %%
dtype = reviews.points.dtype

# %%
point_strings = reviews.points.astype('str')

# %%
len(reviews)-len(reviews.dropna())
# Out:
# 107584

# %%
len(reviews)-len(reviews.price.dropna())
# Out:
# 8996

# %%
reviews.price.isnull().sum()
# Out:
# 8996

# %%
pd.isnull(reviews.price).sum()
# Out:
# 8996

# %%
reviews.region_1.fillna('Unknown').value_counts().sort_values(ascending=False)
# Out:
# region_1
# Unknown        21247
# Napa Valley     4480
#                ...
# Geelong            1
# Paestum            1
# Name: count, Length: 1230, dtype: int64

# %%
reviews.region1 = reviews.region_1.fillna('Unknown')
reviews.groupby('region_1').region_1.size().sort_values(ascending=False)
# Out:
# region_1
# Napa Valley             4480
# Columbia Valley (WA)    4124
#                         ...
# Frascati                   1
# Massachusetts              1
# Name: region_1, Length: 1229, dtype: int64

# %% [markdown]
# # Renaming

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# ...                               ...    ...    ...                ...
# 129969                            NaN     90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline     90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %% [markdown]
# rename() lets you rename index or column values by specifying a index or column keyword parameter, respectively. It supports a variety of input formats, but usually a Python dictionary is the most convenient.

# %%
renamed_review = reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
renamed_review.loc['firstEntry':10]
# Out:
#               country                                        description  \
# firstEntry      Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry  Portugal  This is ripe and fruity, a wine that is smooth...
# ...               ...                                                ...
# 9              France  This has great depth of flavor with its fresh ...
# 10                 US  Soft, supple plum envelopes an oaky structure ...
#
#                 designation  points  price           province     region_1  \
# firstEntry     Vulkà Bianco      87    NaN  Sicily & Sardinia         Etna
# secondEntry        Avidagos      87   15.0              Douro          NaN
# ...                     ...     ...    ...                ...          ...
# 9               Les Natures      87   27.0             Alsace       Alsace
# 10           Mountain Cuvée      87   19.0         California  Napa Valley
#
#             region_2     taster_name taster_twitter_handle  \
# ...

# %% [markdown]
# You'll probably rename columns very often, but rename index values very rarely. For that, **set_index()** is usually more convenient.

# %%
reviews.rename_axis("wines", axis="rows").rename_axis("fields", axis='columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# fields                    designation  points  price           province  \
# wines
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# fields region_1 region_2    taster_name taster_twitter_handle  \
# wines
# ...

# %% [markdown]
# # concat(), join(), and merge()

# %%
canadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")
british_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")

# %%
canadian_youtube.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
british_youtube.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos           25  2017-11-13T01:45:13.000Z
#
# ...

# %%
pd.concat([canadian_youtube, british_youtube])
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# ...            ...           ...
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# ...                                                  ...
# 38914  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 38915  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                  channel_title  category_id              publish_time  \
# 0                   EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1                    iDubbbzTV           23  2017-11-13T17:00:00.000Z
# ...                        ...          ...                       ...
# 38914  Eurovision Song Contest           24  2018-05-08T20:32:32.000Z
# ...

# %% [markdown]
# The middlemost combiner in terms of complexity is join(). join() lets you combine different DataFrame objects which have an index in common. For example, to pull down videos that happened to be trending on the same day in both Canada and the UK, we could do the following:

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_UK')
# Out:
#                                                          video_id_CAN  \
# title                                      trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé 17.14.11       n1WpP7iowLc
# PLUSH - Bad Unboxing Fan Mail              17.14.11       0dBIkQ4Mz1M
# ...                                                               ...
# Trump Advisor Grovels To Trudeau           18.14.06       lbMKLzQ4cNQ
# 【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班           18.14.06       POTgw38-m58
#
#                                                          channel_title_CAN  \
# title                                      trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé 17.14.11             EminemVEVO
# PLUSH - Bad Unboxing Fan Mail              17.14.11              iDubbbzTV
# ...                                                                    ...
# Trump Advisor Grovels To Trudeau           18.14.06        The Young Turks
# ...

# %% [markdown]
# # Barcharts

# %%
import pandas as pd
flight_data = pd.read_csv('/kaggle/input/data-for-datavis/flight_delays.csv')
flight_data
